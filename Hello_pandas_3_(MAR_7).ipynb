# %%
import pandas as pd

df = pd.read_csv("ads (1).csv")

# %% [markdown]
# ## Subsetting by group
#
# - It is very common to select only parts of a dataset for analysis.
# - Examples?

# %% [markdown]
# ## Subsetting by group in pandas
#
# - Pandas gives you a few ways to do this.
# - The one we will focus on is called "boolean indexing"
# - For those coming from SQL, checkout [query](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html) which is similar

# %% [markdown]
# ## Selecting a column
#
# - Recall that to select a column (aka "series") you use this syntax

# %%
df["ad"]
# Out:
# 0      ingredients
# 1      ingredients
# 2      ingredients
# 3      ingredients
# 4             cost
#           ...
# 995           cost
# 996           cost
# 997           cost
# 998           cost
# 999           cost
# Name: ad, Length: 1000, dtype: object

# %% [markdown]
# ## From selection to Boolean indexing
#
# - This is used for Boolean indexing

# %%
df["ad"] == "cost"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: ad, Length: 1000, dtype: bool

# %% [markdown]
# What is that?

# %%
ix = df["ad"] == "cost"
type(ix)
# Out:
# pandas.core.series.Series

# %% [markdown]
# What is this doing?

# %%
df[ix]
# Out:
#      Unnamed: 0    ad  click   age
# 4             4  cost   True   NaN
# 7             7  cost  False   NaN
# 9             9  cost   True  57.0
# 12           12  cost  False  49.0
# 14           14  cost   True   NaN
# ..          ...   ...    ...   ...
# 995         995  cost  False  33.0
# 996         996  cost  False   NaN
# 997         997  cost   True   NaN
# 998         998  cost  False  64.0
# 999         999  cost  False   NaN
#
# [491 rows x 4 columns]

# %%
## another way to write it 

df[df["ad"] == "cost"]
# Out:
#      Unnamed: 0    ad  click   age
# 4             4  cost   True   NaN
# 7             7  cost  False   NaN
# 9             9  cost   True  57.0
# 12           12  cost  False  49.0
# 14           14  cost   True   NaN
# ..          ...   ...    ...   ...
# 995         995  cost  False  33.0
# 996         996  cost  False   NaN
# 997         997  cost   True   NaN
# 998         998  cost  False  64.0
# 999         999  cost  False   NaN
#
# [491 rows x 4 columns]

# %% [markdown]
# ### Where is the for loop?

# %% [markdown]
# # Combining Boolean indexes?

# %%
# What do you notice about this syntax?

df[(df["ad"] == "cost") & (df["age"] < 30)]
# Out:
#      Unnamed: 0    ad  click   age
# 35           35  cost  False  18.0
# 50           50  cost  False  19.0
# 68           68  cost   True  26.0
# 91           91  cost  False  22.0
# 97           97  cost  False  21.0
# ..          ...   ...    ...   ...
# 913         913  cost   True  24.0
# 935         935  cost   True  27.0
# 957         957  cost  False  20.0
# 971         971  cost  False  17.0
# 987         987  cost  False  20.0
#
# [67 rows x 4 columns]

# %% [markdown]
# ### Compute the mean age for those who clicked on the cost ad
#
# - Do you notice any problems? Welcome to data analysis 😀

# %%
df[(df["ad"] == "cost") & (df["click"] == True)].mean().reset_index()
# Out:
# <ipython-input-16-7d42a0c38ae5>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[(df["ad"] == "cost") & (df["click"] == True)].mean().reset_index()
#         index           0
# 0  Unnamed: 0  494.076389
# 1       click    1.000000
# 2         age   45.520548

# %%
# how prof did it

cost_df = df[df["ad"] == "cost"]
cocli_df = cost_df[cost_df["click"] == True]
cocli_df["age"].mean()
# Out:
# 44.732375

# %% [markdown]
# # Possible fixes

# %% [markdown]
# - [fillna](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html)
# - [dropna](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html)

# %%
# fill nulls 
mean = df["age"].mean()
df = df.fillna(mean)

# %%
import pandas as pd
from pandas import DataFrame

filename = 'Class data - Sheet1 (1).csv'

cd = pd.read_csv(filename)

# %%
cd = cd.dropna()

# %%
cd

# %%
cd[(cd["Age"] == "21") & (cd["State"] == "CO")].reset_index()
# Out:
#    index    Person State Age Shoe size      Sign   Chipotle order Dog or Cat?  \
# 0     12        JP    CO  21        10     Cancer         Burrito         Dog
# 1     27     Elise    CO  21         8     Gemini         Burrito         Cat
# 2     37  Greyson     CO  21      10.5      virgo  steak burrito          Dog
# 3     47    Justin    CO  21       9.5  Capricorn            Bowl         dog
#
#                Major   SKI?
# 0           Finance     Ski
# 1  Ops and Analytics    ski
# 2   Finance and Info  board
# 3       info/finance    ski
